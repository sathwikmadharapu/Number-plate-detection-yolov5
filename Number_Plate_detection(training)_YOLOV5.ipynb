# %%
import os

os.environ["KAGGLE_CONFIG_DIR"] = "/content"

# !kaggle datasets download -d madharapusathwik0904/nplate-for-yolov5 --unzip   #link

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt

# %% [markdown]
#  **Wandb is optional**

# %%
# !pip install wandb

# %%
import wandb
wandb.login()

# %% [markdown]
# *  Make sure to point the location for train,test,val images in data.yaml file
# *  And also adjust the epochs based on the GPU available.

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/data.yaml --weights yolov5s.pt --project "Number_Plate_Detection"

# %% [markdown]
# **Point towards the best.pt which will be shown at the output after the training And also Do check for --conf in f1 graph and choose the based on it
# For me it is 0.52**

# %%
# !python detect.py --weights /content/yolov5/Number_Plate_Detection/exp2/weights/best.pt --img 640 --conf 0.52 --source /content/test/images
